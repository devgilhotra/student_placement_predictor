# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('D:\\folder\\Student_Placement_Prediction\\data\\student_placement_synthetic.csv')

# %%
# It will display top 5 rows of dataset
df.head()
# Out:
#      branch college_tier  cgpa  backlogs  coding_skills  dsa_score  \
# 0       ECE       Tier-3  6.70         0            7.6        4.4
# 1  Chemical       Tier-2  5.70         0            5.4        7.9
# 2        EE       Tier-2  7.19         0            5.6        6.8
# 3        CE       Tier-2  6.48         0            5.2        3.1
# 4       CSE       Tier-2  6.71         1            5.9        4.7
#
#    aptitude_score  communication_skills  ml_knowledge  system_design  \
# 0            49.5                   3.7           6.4            0.3
# 1            72.0                   8.3           6.3            1.9
# 2            79.1                   7.4           4.4            5.2
# 3            48.4                   5.0           1.1            6.7
# 4            61.2                   4.3           2.7            2.8
#
#    internships  projects_count  certifications  hackathons  \
# 0            1               4               4           3
# ...

# %%
# It will give number of rowsa and columns
df.shape
# Out:
# (100000, 18)

# %%
# It will display all the columns
df.columns
# Out:
# Index(['branch', 'college_tier', 'cgpa', 'backlogs', 'coding_skills',
#        'dsa_score', 'aptitude_score', 'communication_skills', 'ml_knowledge',
#        'system_design', 'internships', 'projects_count', 'certifications',
#        'hackathons', 'open_source_contributions', 'extracurriculars',
#        'placement_status', 'salary_package_lpa'],
#       dtype='str')

# %%
# It will display about the column names, number of non-null values, data type of each column
approximate memory usage
df.info()
# Out:
#   Cell In[15], line 2
#     approximate memory usage
#                 ^
# SyntaxError: invalid syntax

# %%
# It will give the statistical analysis of data havinh numerical data
df.describe()
# Out:
#                 cgpa       backlogs  coding_skills      dsa_score  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        7.206381       0.547010       5.995147       5.500711
# std         0.925235       0.862727       1.496302       1.781961
# min         4.000000       0.000000       1.000000       1.000000
# 25%         6.580000       0.000000       5.000000       4.300000
# 50%         7.210000       0.000000       6.000000       5.500000
# 75%         7.830000       1.000000       7.000000       6.700000
# max        10.000000       3.000000      10.000000      10.000000
#
#        aptitude_score  communication_skills   ml_knowledge  system_design  \
# count   100000.000000         100000.000000  100000.000000  100000.000000
# mean        64.990511              5.990614       4.508752       4.008210
# std         11.990892              1.496552       1.968278       1.778405
# min         20.000000              1.000000       0.000000       0.000000
# ...

# %%
# check for missing values in each individual cell and return True if value is missing
df.isnull()
# Out:
#        branch  college_tier   cgpa  backlogs  coding_skills  dsa_score  \
# 0       False         False  False     False          False      False
# 1       False         False  False     False          False      False
# 2       False         False  False     False          False      False
# 3       False         False  False     False          False      False
# 4       False         False  False     False          False      False
# ...       ...           ...    ...       ...            ...        ...
# 99995   False         False  False     False          False      False
# 99996   False         False  False     False          False      False
# 99997   False         False  False     False          False      False
# 99998   False         False  False     False          False      False
# 99999   False         False  False     False          False      False
#
#        aptitude_score  communication_skills  ml_knowledge  system_design  \
# ...

# %%
# Checking for null values and displaying how many null values are there in a column
df.isnull().sum()
# Out:
# branch                           0
# college_tier                     0
# cgpa                             0
# backlogs                         0
# coding_skills                    0
# dsa_score                        0
# aptitude_score                   0
# communication_skills             0
# ml_knowledge                     0
# system_design                    0
# internships                      0
# projects_count                   0
# certifications                   0
# hackathons                       0
# open_source_contributions        0
# extracurriculars                 0
# placement_status                 0
# salary_package_lpa           31525
# dtype: int64
